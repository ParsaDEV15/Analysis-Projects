# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Getting Data

# %%
df = pd.read_csv('amazon.csv')
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# 1         ₹349                 43%    4.0       43,994
# 2       ₹1,899                 90%    3.9        7,928
# 3         ₹699                 53%    4.2       94,363
# 4         ₹399                 61%    4.2       16,905
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
# 2  【 Fast Charger& Data Sync】-With built-in safet...
# 3  The boAt Deuce USB 300 2 in 1 cable is compati...
# 4  [CHARGE & SYNC FUNCTION]- This cable comes wit...
#
#                                              user_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2  Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 3  Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# 4  rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1  RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 2  R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# 3  R3EEUZKKK9J36I,R3HJVYCLYOY554,REDECAZ7AMPQC,R1...
# 4  R1BP4L2HH9TFUP,R16PVJEXKV6QZS,R2UPDB81N66T4P,R...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
# 1  A Good Braided Cable for Your Type C Device,Go...
# 2  Good speed for earlier versions,Good Product,W...
# 3  Good product,Good one,Nice,Really nice product...
# 4  As good as original,Decent,Good one for second...
#
#                                       review_content  \
# 0  Looks durable Charging is fine tooNo complains...
# 1  I ordered this cable to connect my phone to An...
# 2  Not quite durable and sturdy,https://m.media-a...
# 3  Good product,long wire,Charges good,Nice,I bou...
# 4  Bought this instead of original apple, does th...
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1  https://m.media-amazon.com/images/W/WEBP_40237...
# 2  https://m.media-amazon.com/images/W/WEBP_40237...
# 3  https://m.media-amazon.com/images/I/41V5FtEWPk...
# 4  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                         product_link
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...
# 2  https://www.amazon.in/Sounce-iPhone-Charging-C...
# 3  https://www.amazon.in/Deuce-300-Resistant-Tang...
# 4  https://www.amazon.in/Portronics-Konnect-POR-1...

# %% [markdown]
# # Exploring Data

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
df.shape
# Out:
# (1465, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
#  15  product_link         1465 non-null   object
# dtypes: object(16)
# memory usage: 183.3+ KB

# %%
df.describe()
# Out:
#         product_id                                       product_name  \
# count         1465                                               1465
# unique        1351                                               1337
# top     B07JW9H4J1  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# freq             3                                                  5
#
#                                                  category discounted_price  \
# count                                                1465             1465
# unique                                                211              550
# top     Computers&Accessories|Accessories&Peripherals|...             ₹199
# freq                                                  233               53
#
#        actual_price discount_percentage rating rating_count  \
# count          1465                1465   1465         1463
# unique          449                  92     28         1143
# top            ₹999                 50%    4.1        9,378
# freq            120                  56    244            9
#
#                                             about_product  \
# count                                                1465
# unique                                               1293
# top     [CHARGE & SYNC FUNCTION]- This cable comes wit...
# freq                                                    6
#
#                                                   user_id  \
# count                                                1465
# unique                                               1194
# top     AHIKJUDTVJ4T6DV6IUGFYZ5LXMPA,AE55KTFVNXYFD5FPY...
# freq                                                   10
#
#                                                 user_name  \
# count                                                1465
# unique                                               1194
# top     $@|\|TO$|-|,Sethu madhav,Akash Thakur,Burger P...
# freq                                                   10
#
#                                                 review_id  \
# count                                                1465
# unique                                               1194
# top     R3F4T5TRYPTMIG,R3DQIEC603E7AY,R1O4Z15FD40PV5,R...
# freq                                                   10
#
#                                              review_title  \
# count                                                1465
# unique                                               1194
# top     Worked on iPhone 7 and didn’t work on XR,Good ...
# freq                                                   10
#
#                                            review_content  \
# count                                                1465
# unique                                               1212
# top     I am not big on camera usage, personally. I wa...
# freq                                                    8
#
#                                                  img_link  \
# count                                                1465
# unique                                               1412
# top     https://m.media-amazon.com/images/I/413sCRKobN...
# freq                                                    3
#
#                                              product_link
# count                                                1465
# unique                                               1465
# top     https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# freq                                                    1

# %% [markdown]
# # Cleaning Data

# %%
df.dropna(inplace=True)
useless_columns = ['user_id', 'user_name', 'review_id', 'review_title','review_content', 'img_link', 'about_product', 'product_link', 'product_id']
df.drop(useless_columns, axis=1, inplace=True)

# %% [markdown]
# ### Changing Data Format

# %%
def format_money(x):
    formatted = x[1:].replace(',', '')
    formatted = np.multiply(np.float32(formatted), 0.0064)
    return np.round(formatted, 2)
    

df[['discounted_price', 'actual_price']] = df[['discounted_price', 'actual_price']].map(format_money)
df['discount_percentage'] = df['discount_percentage'].str.replace('%', '').astype(np.uint8)

df['rating'] = pd.to_numeric(df['rating'], errors='coerce').astype(np.float32)
df.dropna(subset=['rating'], inplace=True)
df['rating_count'] = df['rating_count'].str.replace(',', '').astype(np.uint16)

# %% [markdown]
# ### Adding Columns

# %%
categories = df.join(df['category'].str.split('|', expand=True))

df['main_category'] = categories[0]
df['sub_category'] = categories[1]

df.drop('category', axis=1, inplace=True)


C = df['rating'].mean()
m = 100
df['weighted_rating'] = (df['rating'] * df['rating_count']) / (df['rating_count'] + m) + (C * m) / (df['rating_count'] + m)


conditions = [
    df['weighted_rating'] > 4.5,
    df['weighted_rating'] > 3.5,
    df['weighted_rating'] <= 3.5
]

labels = ['Good Rated', 'Average Rated', 'Poor Rated']

df['rating_label'] = np.select(conditions, labels)

# %% [markdown]
# ### Checking Duplicates

# %%
print(df.duplicated().sum())
df.drop_duplicates(inplace=True)
# Out:
# 91

# %% [markdown]
# #### Exploring Cleaned Data

# %%
df.head()
# Out:
#                                         product_name  discounted_price  \
# 0  Wayona Nylon Braided USB to Lightning Fast Cha...              2.55
# 1  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...              1.27
# 2  Sounce Fast Phone Charging Cable & Data Sync U...              1.27
# 3  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...              2.11
# 4  Portronics Konnect L 1.2M Fast Charging 3A 8 P...              0.99
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0          7.03                   64     4.2         24269
# 1          2.23                   43     4.0         43994
# 2         12.15                   90     3.9          7928
# 3          4.47                   53     4.2         28827
# 4          2.55                   61     4.2         16905
#
#            main_category             sub_category  weighted_rating  \
# 0  Computers&Accessories  Accessories&Peripherals         4.199576
# 1  Computers&Accessories  Accessories&Peripherals         4.000219
# 2  Computers&Accessories  Accessories&Peripherals         3.902451
# 3  Computers&Accessories  Accessories&Peripherals         4.199643
# 4  Computers&Accessories  Accessories&Peripherals         4.199393
#
#     rating_label
# 0  Average Rated
# 1  Average Rated
# 2  Average Rated
# 3  Average Rated
# 4  Average Rated

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1371 entries, 0 to 1464
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_name         1371 non-null   object
#  1   discounted_price     1371 non-null   float64
#  2   actual_price         1371 non-null   float64
#  3   discount_percentage  1371 non-null   uint8
#  4   rating               1371 non-null   float32
#  5   rating_count         1371 non-null   uint16
#  6   main_category        1371 non-null   object
#  7   sub_category         1371 non-null   object
#  8   weighted_rating      1371 non-null   float64
#  9   rating_label         1371 non-null   object
# dtypes: float32(1), float64(3), object(4), uint16(1), uint8(1)
# memory usage: 95.1+ KB

# %%
sns.color_palette("icefire", as_cmap=True)
sns.set_style("whitegrid")

# %% [markdown]
# # Correlation

# %%
corr_df = df[['actual_price', 'discount_percentage', 'discounted_price', 'rating', 'rating_count']]
corr = corr_df.corr()

sns.heatmap(corr, annot=True)
sns.pairplot(corr_df)

plt.show()

# %% [markdown]
# # Analysing

# %% [markdown]
# ### Counting All Groups of Rated Products

# %%
sns.countplot(x='rating_label', hue='rating_label', data=df)
plt.title('Product Rating Distribution')
plt.show()

# %% [markdown]
# ### Poor and Good Rated Products

# %%
good_rated = df[df['rating_label'] == 'Good Rated'][['product_name', 'weighted_rating']]
bad_rated = df[df['rating_label'] == 'Poor Rated'][['product_name', 'weighted_rating']]

fig, axs = plt.subplots(2, 1, figsize=(15, 25))

ax1 = sns.barplot(ax=axs[0], data=bad_rated, x='weighted_rating', y='product_name', hue='product_name')
ax1.set_title('Bad Rated Product')
for i in ax1.containers:
    ax1.bar_label(i, fontsize=10)

ax2 = sns.barplot(ax=axs[1], data=good_rated, x='weighted_rating', y='product_name', hue='product_name')
ax2.set_title('Bad Rated Product')
for i in ax2.containers:
    ax2.bar_label(i, fontsize=10)

plt.show()

# %% [markdown]
# ### Good Rated Products With High Discount Rate

# %%
high_discount_rate = df[(df['discount_percentage'] >= 60) & (df['rating_label'] == 'Good Rated')][['product_name', 'discount_percentage', 'weighted_rating']]

plt.figure(figsize=(10,8))
ax = sns.barplot(x='weighted_rating', y='product_name', hue='discount_percentage', data=high_discount_rate)

for i in ax.containers:
    ax.bar_label(i, fontsize=10)

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Small Rating Count But With Good Rating Products With Low Discount Rate

# %%
low_discount_rate = df[(df['discount_percentage'] <= 30) & (df['rating'] >= 4) & (df['rating_count'] <= m)][['product_name', 'discount_percentage', 'rating', 'rating_count']]

plt.figure(figsize=(10,8))
ax = sns.barplot(x='rating_count', y='product_name', hue='discount_percentage',data=low_discount_rate)

for i in ax.containers:
    ax.bar_label(i, fontsize=10)

plt.show()

# %% [markdown]
# ### Products Actual Price, Rating Count, Weighted Rating, Discount Rate  Distribution

# %%
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(20,10))

sns.histplot(ax=axs[0,0], data=df, x='actual_price', kde=True, bins=50, color='r')
sns.histplot(ax=axs[0,1], data=df, x='rating_count', kde=True, bins=50, color='g')
sns.histplot(ax=axs[1,0], data=df, x='weighted_rating', kde=True, bins=20, color='b')
sns.histplot(ax=axs[1,1], data=df, x='discount_percentage', kde=True, bins=30, color='y')

plt.show()

# %% [markdown]
# ### Checking Main Categories and Sub Category

# %%
main_categories = df['main_category'].value_counts().reset_index()
sub_categories = df['sub_category'].value_counts().reset_index()

fig, axs = plt.subplots(nrows=2, ncols=1, figsize=(12,13))

ax1 = sns.barplot(ax=axs[0], x='count', y='main_category', hue='main_category', data=main_categories)
axs[0].set(title='Main Categories')
for i in ax1.containers:
    ax1.bar_label(i, fontsize=10)

ax2 = sns.barplot(ax=axs[1], x='count', y='sub_category', hue='sub_category',data=sub_categories)
axs[1].set(title='Sub Categories')
for i in ax2.containers:
    ax2.bar_label(i, fontsize=10)

plt.show()

# %% [markdown]
# Main and sub Categories Price Range

# %%
fig, axs = plt.subplots(2, 1, figsize=(18,20))

sns.boxplot(ax=axs[0], data=df, x='actual_price', y='main_category', hue='main_category')
axs[0].set_xticks(np.arange(0, 1000, 20))
axs[0].set_title('Main Categories Discount Percentage')

sns.boxplot(ax=axs[1], data=df, x='actual_price', y='sub_category', hue='sub_category')
axs[1].set_xticks(np.arange(0, 1000, 20))
axs[1].set_title('Sub Categories Discount Percentage')
plt.show()

# %% [markdown]
# ### Main and sub Categories Discount Range

# %%
fig, axs = plt.subplots(2, 1, figsize=(18,15))

sns.boxplot(ax=axs[0], data=df, x='discount_percentage', y='main_category', hue='main_category')
axs[0].set_xticks(np.arange(0, 100, 5))
axs[0].set_title('Main Categories Discount Percentage')

sns.boxplot(ax=axs[1], data=df, x='discount_percentage', y='sub_category', hue='sub_category')
axs[1].set_xticks(np.arange(0, 100, 5))
axs[1].set_title('Sub Categories Discount Percentage')
plt.show()
